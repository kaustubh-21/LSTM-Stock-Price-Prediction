# %% [markdown]
# #### Import necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional, Conv1D
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read csv and select the stock for which you wanna predict future price

# %%
df = pd.read_csv('prices-split-adjusted.csv')
pg = df[df['symbol'] == 'HAL']  ## change 'HAL' with your choice of stock 
pg
# Out:
#               date symbol       open      close        low       high  \
# 448     2010-01-04    HAL  30.719999  31.250000  30.660000  31.340000
# 916     2010-01-05    HAL  31.280001  31.650000  30.990000  31.830000
# 1384    2010-01-06    HAL  31.740000  32.400002  31.639999  32.590000
# 1852    2010-01-07    HAL  32.310001  32.480000  31.920000  32.520000
# 2320    2010-01-08    HAL  32.950001  34.119999  32.490002  34.139999
# ...            ...    ...        ...        ...        ...        ...
# 848972  2016-12-23    HAL  55.040001  54.840000  54.630001  55.259998
# 849472  2016-12-27    HAL  55.020000  54.910000  54.700001  55.540001
# 849972  2016-12-28    HAL  55.110001  54.299999  54.180000  55.220001
# 850472  2016-12-29    HAL  54.139999  54.040001  53.840000  54.459999
# 850972  2016-12-30    HAL  54.029999  54.090000  53.610001  54.360001
#
#             volume
# 448     11571600.0
# 916     18989700.0
# 1384    15720800.0
# 1852     8993100.0
# 2320    23014600.0
# ...            ...
# 848972   3161500.0
# 849472   3608700.0
# 849972   4759700.0
# 850472   4216800.0
# 850972   4638300.0
#
# [1762 rows x 7 columns]

# %%
pg.drop('symbol', axis = 1,  inplace=True)
pg.drop('open', axis = 1,  inplace=True)
pg.drop('low', axis = 1,  inplace=True)
pg.drop('high', axis = 1,  inplace=True)
pg.drop('volume', axis = 1,  inplace=True)
pg.drop('date', axis = 1,  inplace=True)
# Out:
# c:\users\kaust\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# #### At this point we can include different technical indicators like moving averages, bollinger bands, RSI etc, but I found that raw data worked out the best with least RMS
#
# ### I have included "Exponential Moving Average" in another code, you can check it out there

# %%
plt.figure(figsize=(16,8))
plt.plot(pg['close'], label='Close Price history')

# %%
dataset = pg.values
train = dataset[0:1500,:]
valid = dataset[1500:,:]

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) # Normalize the data
scaled_data = scaler.fit_transform(dataset)

# %% [markdown]
# #### Now we set our training data, I will feed the data of last 60 days to predict the new price, you can try your version of code with any other choice for number of days.
#
# #### If you increase the number of days the network will take longer time to learn.
#
# #### I've tried 30 days, 60 days and 90 days, and I have noticed that the rms(root mean square) error do not decrease significantly after 60 days.

# %%
x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %% [markdown]
# #### The model, 2 dense layers with activation function 'tanh', a Convolutional 1D layer and a Bidirectional LSTM and finally and output layer.
#
# #### I tried varying the number of layers from single LSTM layer to upto 4 dense layer with different number of nodes in each layer, activation functions like 'relu', 'tanh', 'sigmoid' and their combinations, and found that the following model works the best.
#
# #### I also tried dropout in hope to improve the results but it doesn't work out as I expected.

# %%
model = Sequential()
model.add(Dense(20,activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(Conv1D(filters=32, kernel_size=3,strides=1, padding="causal", activation="relu", input_shape=[None, 1]))
model.add(Bidirectional(LSTM(units=32)))
model.add(Dense(1))

# %% [markdown]
# #### I tried various optimizers, epoch number and batch size.
#
# #### Adam works very good and fast, loss after 100 epochs never reduced significantly.

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mae'])
history = model.fit(x_train, y_train, epochs=100, batch_size=128, verbose=1, validation_split = 0.15)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 30s 372ms/step - loss: 0.0835 - mae: 0.2165 - val_loss: 0.0326 - val_mae: 0.1741
# Epoch 2/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0199 - mae: 0.1169 - val_loss: 0.0026 - val_mae: 0.0404
# Epoch 3/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0115 - mae: 0.0813 - val_loss: 0.0023 - val_mae: 0.0383
# Epoch 4/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0062 - mae: 0.0611 - val_loss: 0.0036 - val_mae: 0.0490
# Epoch 5/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0041 - mae: 0.0479 - val_loss: 0.0014 - val_mae: 0.0284
# Epoch 6/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0032 - mae: 0.0407 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 7/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0027 - mae: 0.0387 - val_loss: 0.0013 - val_mae: 0.0272
# Epoch 8/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0023 - mae: 0.0347 - val_loss: 9.7573e-04 - val_mae: 0.0230
# Epoch 9/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0020 - mae: 0.0325 - val_loss: 0.0010 - val_mae: 0.0238
# Epoch 10/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0017 - mae: 0.0299 - val_loss: 8.4485e-04 - val_mae: 0.0213
# Epoch 11/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0015 - mae: 0.0274 - val_loss: 7.5217e-04 - val_mae: 0.0201
# Epoch 12/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 7.9432e-04 - val_mae: 0.0211
# Epoch 13/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 7.2586e-04 - val_mae: 0.0202
# Epoch 14/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 6.9129e-04 - val_mae: 0.0197
# Epoch 15/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 6.8708e-04 - val_mae: 0.0197
# Epoch 16/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 7.0135e-04 - val_mae: 0.0199
# Epoch 17/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 6.9146e-04 - val_mae: 0.0198
# Epoch 18/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 6.8167e-04 - val_mae: 0.0196
# Epoch 19/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0010 - mae: 0.0237 - val_loss: 6.8694e-04 - val_mae: 0.0197
# Epoch 20/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 6.6132e-04 - val_mae: 0.0193
# Epoch 21/100
# 10/10 [==============================] - 1s 88ms/step - loss: 9.8504e-04 - mae: 0.0233 - val_loss: 6.6408e-04 - val_mae: 0.0194
# Epoch 22/100
# 10/10 [==============================] - 1s 90ms/step - loss: 9.7015e-04 - mae: 0.0231 - val_loss: 6.5030e-04 - val_mae: 0.0190
# Epoch 23/100
# 10/10 [==============================] - 1s 89ms/step - loss: 9.5541e-04 - mae: 0.0230 - val_loss: 6.5031e-04 - val_mae: 0.0191
# Epoch 24/100
# 10/10 [==============================] - 1s 88ms/step - loss: 9.4144e-04 - mae: 0.0228 - val_loss: 6.3714e-04 - val_mae: 0.0187
# Epoch 25/100
# 10/10 [==============================] - 1s 89ms/step - loss: 9.3241e-04 - mae: 0.0226 - val_loss: 6.3531e-04 - val_mae: 0.0187
# Epoch 26/100
# 10/10 [==============================] - 1s 89ms/step - loss: 9.2317e-04 - mae: 0.0225 - val_loss: 6.2356e-04 - val_mae: 0.0185
# Epoch 27/100
# 10/10 [==============================] - 1s 90ms/step - loss: 9.0512e-04 - mae: 0.0224 - val_loss: 6.2508e-04 - val_mae: 0.0186
# Epoch 28/100
# 10/10 [==============================] - 1s 89ms/step - loss: 8.9398e-04 - mae: 0.0221 - val_loss: 6.1683e-04 - val_mae: 0.0185
# Epoch 29/100
# 10/10 [==============================] - 1s 85ms/step - loss: 8.8650e-04 - mae: 0.0221 - val_loss: 6.2094e-04 - val_mae: 0.0187
# Epoch 30/100
# 10/10 [==============================] - 1s 87ms/step - loss: 8.7783e-04 - mae: 0.0218 - val_loss: 6.0194e-04 - val_mae: 0.0182
# Epoch 31/100
# 10/10 [==============================] - 1s 91ms/step - loss: 8.5312e-04 - mae: 0.0217 - val_loss: 5.9867e-04 - val_mae: 0.0182
# Epoch 32/100
# 10/10 [==============================] - 1s 90ms/step - loss: 8.4109e-04 - mae: 0.0215 - val_loss: 5.9030e-04 - val_mae: 0.0181
# Epoch 33/100
# 10/10 [==============================] - 1s 91ms/step - loss: 8.2550e-04 - mae: 0.0212 - val_loss: 5.9316e-04 - val_mae: 0.0182
# Epoch 34/100
# 10/10 [==============================] - 1s 92ms/step - loss: 8.0872e-04 - mae: 0.0211 - val_loss: 5.6992e-04 - val_mae: 0.0176
# Epoch 35/100
# 10/10 [==============================] - 1s 87ms/step - loss: 7.9798e-04 - mae: 0.0208 - val_loss: 5.6167e-04 - val_mae: 0.0173
# Epoch 36/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.8946e-04 - mae: 0.0208 - val_loss: 5.6538e-04 - val_mae: 0.0173
# Epoch 37/100
# 10/10 [==============================] - 1s 87ms/step - loss: 7.8111e-04 - mae: 0.0207 - val_loss: 5.4997e-04 - val_mae: 0.0173
# Epoch 38/100
# 10/10 [==============================] - 1s 89ms/step - loss: 7.6785e-04 - mae: 0.0205 - val_loss: 5.8211e-04 - val_mae: 0.0182
# Epoch 39/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.4863e-04 - mae: 0.0202 - val_loss: 5.3667e-04 - val_mae: 0.0170
# Epoch 40/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.2783e-04 - mae: 0.0199 - val_loss: 5.3726e-04 - val_mae: 0.0169
# Epoch 41/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.4139e-04 - mae: 0.0200 - val_loss: 5.2024e-04 - val_mae: 0.0166
# Epoch 42/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.9569e-04 - mae: 0.0195 - val_loss: 5.1487e-04 - val_mae: 0.0167
# Epoch 43/100
# 10/10 [==============================] - 1s 88ms/step - loss: 6.8331e-04 - mae: 0.0193 - val_loss: 5.0569e-04 - val_mae: 0.0164
# Epoch 44/100
# 10/10 [==============================] - 1s 92ms/step - loss: 6.7804e-04 - mae: 0.0193 - val_loss: 4.9862e-04 - val_mae: 0.0162
# Epoch 45/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.6537e-04 - mae: 0.0192 - val_loss: 4.9819e-04 - val_mae: 0.0165
# Epoch 46/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.6858e-04 - mae: 0.0193 - val_loss: 5.5735e-04 - val_mae: 0.0181
# Epoch 47/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.6792e-04 - mae: 0.0191 - val_loss: 5.4360e-04 - val_mae: 0.0178
# Epoch 48/100
# 10/10 [==============================] - 1s 86ms/step - loss: 6.4977e-04 - mae: 0.0188 - val_loss: 4.7951e-04 - val_mae: 0.0162
# Epoch 49/100
# 10/10 [==============================] - 1s 92ms/step - loss: 6.2213e-04 - mae: 0.0185 - val_loss: 4.6038e-04 - val_mae: 0.0157
# Epoch 50/100
# 10/10 [==============================] - 1s 88ms/step - loss: 5.9957e-04 - mae: 0.0181 - val_loss: 4.6956e-04 - val_mae: 0.0161
# Epoch 51/100
# 10/10 [==============================] - 1s 90ms/step - loss: 5.9108e-04 - mae: 0.0179 - val_loss: 4.5235e-04 - val_mae: 0.0157
# Epoch 52/100
# 10/10 [==============================] - 1s 88ms/step - loss: 5.7837e-04 - mae: 0.0178 - val_loss: 4.5123e-04 - val_mae: 0.0157
# Epoch 53/100
# 10/10 [==============================] - 1s 90ms/step - loss: 5.7184e-04 - mae: 0.0178 - val_loss: 4.6483e-04 - val_mae: 0.0161
# Epoch 54/100
# 10/10 [==============================] - 1s 91ms/step - loss: 5.7399e-04 - mae: 0.0178 - val_loss: 4.4988e-04 - val_mae: 0.0158
# Epoch 55/100
# 10/10 [==============================] - 1s 89ms/step - loss: 5.8182e-04 - mae: 0.0179 - val_loss: 4.2595e-04 - val_mae: 0.0151
# Epoch 56/100
# 10/10 [==============================] - 1s 90ms/step - loss: 5.4358e-04 - mae: 0.0171 - val_loss: 4.2256e-04 - val_mae: 0.0151
# Epoch 57/100
# 10/10 [==============================] - 1s 89ms/step - loss: 5.3046e-04 - mae: 0.0170 - val_loss: 4.1511e-04 - val_mae: 0.0149
# Epoch 58/100
# 10/10 [==============================] - 1s 85ms/step - loss: 5.2642e-04 - mae: 0.0169 - val_loss: 4.1094e-04 - val_mae: 0.0149
# Epoch 59/100
# 10/10 [==============================] - 1s 87ms/step - loss: 5.1696e-04 - mae: 0.0168 - val_loss: 4.2909e-04 - val_mae: 0.0154
# Epoch 60/100
# 10/10 [==============================] - 1s 89ms/step - loss: 5.1975e-04 - mae: 0.0169 - val_loss: 4.0359e-04 - val_mae: 0.0148
# Epoch 61/100
# 10/10 [==============================] - 1s 93ms/step - loss: 5.1479e-04 - mae: 0.0166 - val_loss: 3.9643e-04 - val_mae: 0.0147
# Epoch 62/100
# 10/10 [==============================] - 1s 88ms/step - loss: 4.9753e-04 - mae: 0.0165 - val_loss: 4.1988e-04 - val_mae: 0.0154
# Epoch 63/100
# 10/10 [==============================] - 1s 89ms/step - loss: 4.8878e-04 - mae: 0.0162 - val_loss: 3.9191e-04 - val_mae: 0.0147
# Epoch 64/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.7778e-04 - mae: 0.0163 - val_loss: 3.9594e-04 - val_mae: 0.0148
# Epoch 65/100
# 10/10 [==============================] - 1s 89ms/step - loss: 4.6961e-04 - mae: 0.0160 - val_loss: 3.7955e-04 - val_mae: 0.0144
# Epoch 66/100
# 10/10 [==============================] - 1s 92ms/step - loss: 4.7220e-04 - mae: 0.0161 - val_loss: 3.8458e-04 - val_mae: 0.0145
# Epoch 67/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.6196e-04 - mae: 0.0160 - val_loss: 3.7296e-04 - val_mae: 0.0144
# Epoch 68/100
# 10/10 [==============================] - 1s 88ms/step - loss: 4.4845e-04 - mae: 0.0156 - val_loss: 3.6975e-04 - val_mae: 0.0144
# Epoch 69/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.4988e-04 - mae: 0.0156 - val_loss: 3.7806e-04 - val_mae: 0.0147
# Epoch 70/100
# 10/10 [==============================] - 1s 94ms/step - loss: 4.6107e-04 - mae: 0.0161 - val_loss: 4.7942e-04 - val_mae: 0.0175
# Epoch 71/100
# 10/10 [==============================] - 1s 89ms/step - loss: 4.8825e-04 - mae: 0.0164 - val_loss: 3.8226e-04 - val_mae: 0.0148
# Epoch 72/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.5812e-04 - mae: 0.0160 - val_loss: 4.0853e-04 - val_mae: 0.0157
# Epoch 73/100
# 10/10 [==============================] - 1s 88ms/step - loss: 4.4646e-04 - mae: 0.0157 - val_loss: 3.5358e-04 - val_mae: 0.0141
# Epoch 74/100
# 10/10 [==============================] - 1s 92ms/step - loss: 4.3106e-04 - mae: 0.0153 - val_loss: 3.5238e-04 - val_mae: 0.0141
# Epoch 75/100
# 10/10 [==============================] - 1s 93ms/step - loss: 4.1228e-04 - mae: 0.0149 - val_loss: 3.5434e-04 - val_mae: 0.0143
# Epoch 76/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.2802e-04 - mae: 0.0154 - val_loss: 3.8542e-04 - val_mae: 0.0153
# Epoch 77/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.1714e-04 - mae: 0.0150 - val_loss: 3.4042e-04 - val_mae: 0.0139
# Epoch 78/100
# 10/10 [==============================] - 1s 90ms/step - loss: 4.1771e-04 - mae: 0.0151 - val_loss: 3.3663e-04 - val_mae: 0.0139
# Epoch 79/100
# 10/10 [==============================] - 1s 93ms/step - loss: 4.0756e-04 - mae: 0.0148 - val_loss: 3.3588e-04 - val_mae: 0.0138
# Epoch 80/100
# 10/10 [==============================] - 1s 96ms/step - loss: 4.0078e-04 - mae: 0.0148 - val_loss: 3.3617e-04 - val_mae: 0.0140
# Epoch 81/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.0414e-04 - mae: 0.0148 - val_loss: 3.6992e-04 - val_mae: 0.0149
# Epoch 82/100
# 10/10 [==============================] - 1s 86ms/step - loss: 4.3287e-04 - mae: 0.0155 - val_loss: 3.7828e-04 - val_mae: 0.0154
# Epoch 83/100
# 10/10 [==============================] - 1s 94ms/step - loss: 3.9035e-04 - mae: 0.0147 - val_loss: 3.2617e-04 - val_mae: 0.0138
# Epoch 84/100
# 10/10 [==============================] - 1s 90ms/step - loss: 3.7735e-04 - mae: 0.0142 - val_loss: 3.3047e-04 - val_mae: 0.0140
# Epoch 85/100
# 10/10 [==============================] - 1s 93ms/step - loss: 3.8803e-04 - mae: 0.0146 - val_loss: 3.3725e-04 - val_mae: 0.0143
# Epoch 86/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.1566e-04 - mae: 0.0153 - val_loss: 3.2712e-04 - val_mae: 0.0139
# Epoch 87/100
# 10/10 [==============================] - 1s 94ms/step - loss: 3.9315e-04 - mae: 0.0148 - val_loss: 3.3507e-04 - val_mae: 0.0143
# Epoch 88/100
# 10/10 [==============================] - 1s 93ms/step - loss: 3.7793e-04 - mae: 0.0145 - val_loss: 3.2055e-04 - val_mae: 0.0138
# Epoch 89/100
# 10/10 [==============================] - 1s 92ms/step - loss: 3.7296e-04 - mae: 0.0143 - val_loss: 3.5049e-04 - val_mae: 0.0148
# Epoch 90/100
# 10/10 [==============================] - 1s 92ms/step - loss: 3.6820e-04 - mae: 0.0142 - val_loss: 3.1883e-04 - val_mae: 0.0138
# Epoch 91/100
# 10/10 [==============================] - 1s 90ms/step - loss: 3.6705e-04 - mae: 0.0141 - val_loss: 3.1595e-04 - val_mae: 0.0137
# Epoch 92/100
# 10/10 [==============================] - 1s 91ms/step - loss: 4.0253e-04 - mae: 0.0150 - val_loss: 3.8978e-04 - val_mae: 0.0160
# Epoch 93/100
# 10/10 [==============================] - 1s 91ms/step - loss: 3.8901e-04 - mae: 0.0145 - val_loss: 3.1588e-04 - val_mae: 0.0138
# Epoch 94/100
# 10/10 [==============================] - 1s 88ms/step - loss: 3.7448e-04 - mae: 0.0143 - val_loss: 3.0711e-04 - val_mae: 0.0135
# Epoch 95/100
# 10/10 [==============================] - 1s 91ms/step - loss: 3.7531e-04 - mae: 0.0143 - val_loss: 3.0664e-04 - val_mae: 0.0135
# Epoch 96/100
# 10/10 [==============================] - 1s 88ms/step - loss: 3.5592e-04 - mae: 0.0139 - val_loss: 3.0695e-04 - val_mae: 0.0136
# Epoch 97/100
# 10/10 [==============================] - 1s 87ms/step - loss: 3.5293e-04 - mae: 0.0139 - val_loss: 3.1382e-04 - val_mae: 0.0139
# Epoch 98/100
# 10/10 [==============================] - 1s 91ms/step - loss: 3.5798e-04 - mae: 0.0140 - val_loss: 3.1538e-04 - val_mae: 0.0140
# Epoch 99/100
# 10/10 [==============================] - 1s 89ms/step - loss: 3.6644e-04 - mae: 0.0142 - val_loss: 3.0704e-04 - val_mae: 0.0136
# Epoch 100/100
# 10/10 [==============================] - 1s 91ms/step - loss: 3.5594e-04 - mae: 0.0139 - val_loss: 3.0879e-04 - val_mae: 0.0138

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 60, 20)            40
#
#  dense_1 (Dense)             (None, 60, 10)            210
#
#  conv1d (Conv1D)             (None, 60, 32)            992
#
#  bidirectional (Bidirectiona  (None, 64)               16640
#  l)
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17,947
# Trainable params: 17,947
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Test set

# %%
inputs = pg[len(pg) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %% [markdown]
# #### ROOT MEAN SQUARED ERROR

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 0.9110741838883797

# %% [markdown]
# #### MEAN ABSOLUTE ERROR

# %%
mae=(np.mean(abs(valid-closing_price)))
mae
# Out:
# 0.6920477682322728

# %%
train = pg[:1500]
valid = pg[1500:]
valid['Predictions'] = closing_price
plt.figure(figsize=(16,8))
plt.plot(valid[['close','Predictions']]) # predictions over test set
plt.legend(['Real', 'Predicted'])
# Out:
# <ipython-input-14-e5ebdeb26b25>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price

# %%
s = pg[len(pg) - 60:].values
s = s.reshape(-1,1)
s = scaler.transform(s)

# %%
s = np.reshape(s, (s.shape[1],s.shape[0],1))
closing_price = model.predict(s)
closing_price = scaler.inverse_transform(closing_price)
closing_price # next day closing price
# Out:
# array([[54.36455]], dtype=float32)
